# %% [markdown]
# A sequence of numbers is called an arithmetic progression if the difference between any two consecutive elements is the same.
#
# Given an array of numbers arr, return true if the array can be rearranged to form an arithmetic progression. Otherwise, return false.

# %%
class Solution:
    def canMakeArithmeticProgression(self, arr):
        if len(arr) < 3:
            return True
        arr.sort()
        dif = [arr[i] - arr[i-1] for i in range(1, len(arr))]
        if min(dif) != max(dif):
            return False
        return True

# %%
class Solution:
    def canMakeArithmeticProgression(self, arr):
        arr.sort()
        dif = arr[1] - arr[0]
        for i in range(2, len(arr)):
            if arr[i] - arr[i-1] != dif:
                return False
        return True

# %%
prov = Solution()

# Example 1:
nums = [3,5,1]
# Output: true
print(prov.canMakeArithmeticProgression(nums))


# Example 2:
nums = [1, 2, 4]
# Output: false
print(prov.canMakeArithmeticProgression(nums))

# Example 3:
nums = [-13,-17,-8,-10,-20,2,3,-19,2,-18,-5,7,-12,18,-17,12,-1]
# Output: true
print(prov.canMakeArithmeticProgression(nums))

# Example 4:
nums = [9, 9]
# Output:
print(prov.canMakeArithmeticProgression(nums))
# Out:
# True
# False
# False
# True
